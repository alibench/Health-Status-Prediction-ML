# %%
# %load_ext autoreload
# %autoreload 2
from test_project1_public import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from test_project1_public import *
#
# File ~/Desktop/ML/ml-project-1-mmlt/project1/grading_tests/test_project1_public.py:6
#       3 import numpy as np
#       4 import pytest
# ----> 6 from conftest import ATOL, GITHUB_LINK, RTOL
#       8 FUNCTIONS = [
#       9     "mean_squared_error_gd",
#      10     "mean_squared_error_sgd",
#    (...)
#      14     "reg_logistic_regression",
#      15 ]
#      18 MAX_ITERS = 2
#
# File ~/Desktop/ML/ml-project-1-mmlt/project1/grading_tests/conftest.py:6
#       3 import shutil
#       4 import sys
# ----> 6 import git  # pip install gitpython
# ...

# %%
test_github_link_format()
